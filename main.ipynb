# %%
import pandas as pd

# %%
csv_file = "Resources/CandidateSummaryAction1.csv"

# %%
df = pd.read_csv(csv_file)

# %%
df.columns
# Out:
# Index(['can_id', 'can_nam', 'can_off', 'can_off_sta', 'can_off_dis',
#        'can_par_aff', 'can_inc_cha_ope_sea', 'can_str1', 'can_str2', 'can_cit',
#        'can_sta', 'can_zip', 'ind_ite_con', 'ind_uni_con', 'ind_con',
#        'par_com_con', 'oth_com_con', 'can_con', 'tot_con',
#        'tra_fro_oth_aut_com', 'can_loa', 'oth_loa', 'tot_loa',
#        'off_to_ope_exp', 'off_to_fun', 'off_to_leg_acc', 'oth_rec', 'tot_rec',
#        'ope_exp', 'exe_leg_acc_dis', 'fun_dis', 'tra_to_oth_aut_com',
#        'can_loa_rep', 'oth_loa_rep', 'tot_loa_rep', 'ind_ref', 'par_com_ref',
#        'oth_com_ref', 'tot_con_ref', 'oth_dis', 'tot_dis',
#        'cas_on_han_beg_of_per', 'cas_on_han_clo_of_per', 'net_con',
#        'net_ope_exp', 'deb_owe_by_com', 'deb_owe_to_com', 'cov_sta_dat',
#        'cov_end_dat', 'winner', 'votes'],
#       dtype='object')

# %%
columns = ['can_id', 'can_nam', 'can_off', 'can_off_sta', 'can_off_dis','can_par_aff',
    'ind_ite_con', 'ind_uni_con', 'ind_con', 'tot_con','ope_exp', 'winner', 'votes']

# %%
new_df = pd.DataFrame(df, columns=columns)

# %%
new_df.loc[new_df['winner'] == 'Y'].sort_values('tot_con')
# Out:
#          can_id                    can_nam can_off can_off_sta  can_off_dis  \
# 28    H8OH05036    LATTA, ROBERT EDWARD MR       H          OH          5.0
# 157   H2MI05119          KILDEE, DANIEL T.       H          MI          5.0
# 105   H0PA10078     MARINO, THOMAS ANTHONY       H          PA         10.0
# 92    H6MD07160         CUMMINGS, ELIJAH E       H          MD          7.0
# 128   H6MS01131          KELLY, JOHN TRENT       H          MS          1.0
# ...         ...                        ...     ...         ...          ...
# 153   H8CA04152         MCCLINTOCK, THOMAS       H          CA          4.0
# 358   H2CA43245               TAKANO, MARK       H          CA         41.0
# 244   H2MD02160  RUPPERSBERGER, C.A. DUTCH       H          MD          2.0
# 169   H2TN07103             KUSTOFF, DAVID       H          TN          8.0
# 1250  H4PA13199           BOYLE, BRENDAN F       H          PA         13.0
#
# ...
